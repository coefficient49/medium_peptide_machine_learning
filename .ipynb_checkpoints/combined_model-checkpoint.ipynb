# %%
## for data wrangling
from util_tools import *
# import util_tools
import pandas as pd
import numpy as np

## for plotting
import seaborn as sns
import matplotlib.pyplot as plt

## for reproducibility
from numpy.random import seed
import tensorflow

## for machine learning
from sklearn.model_selection import train_test_split, GroupShuffleSplit,ShuffleSplit
from scipy.stats import spearmanr,pearsonr,zscore

import xgboost as xgb

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from collections import Counter

# from keras.layers.embeddings import Embedding
training,testing=get_HLA_A_02_01()
# Out:
# local training file found... loading...
# local testing file found... loading...

# %%
onehot = encoder("onehot")
blosum = encoder("blosum62")
reducedProp =encoder("reducedProp")
embedding =encoder("embedding")

# %%
Peptide_9mers = training.query("peptide_length == 9")
seqs = Peptide_9mers.loc[:,"sequence"]
off_set = Peptide_9mers["inequality"].map({"=":0,">":2,"<":4})
meas = Peptide_9mers.loc[:,"meas"].apply(np.log10)
# meas = from_ic50(Peptide_9mers.loc[:,"meas"]) +off_set
# seqs = seqspep
# Peptide_9mers
blosum_seqs = [blosum.encode(x) for x in seqs]
onehot_seqs = [onehot.encode(x) for x in seqs]
reducedProp_seqs = [reducedProp.encode(x) for x in seqs]
embedding_seqs = [embedding.encode(x) for x in seqs]

# %%
def build_model():

    blosum62_input = Input(shape=(20,9,1))
    onehot_input = Input(shape=(24,9,1))
    embedding_input = Input(shape=(None,))

    
    bhidden1 = Conv2D(16,7,activation="elu",padding="same")(blosum62_input)
    bhidden2 = Conv2D(16,5,activation="elu",padding="same")(bhidden1)
    bhidden2  = BatchNormalization()(bhidden2)
    bhidden3 = Conv2D(8,5,activation="elu",padding="same")(bhidden2)
    bhidden4 = Conv2D(8,3,activation="elu",padding="same")(bhidden3)
    bhidden4  = BatchNormalization()(bhidden4)
    bflatten = Flatten()(bhidden4)
    
    
    ohidden1 = Conv2D(16,7,activation="elu",padding="same")(onehot_input)
    ohidden2 = Conv2D(16,5,activation="elu",padding="same")(ohidden1)
    ohidden2  = BatchNormalization()(ohidden2)
    ohidden3 = Conv2D(8,5,activation="elu",padding="same")(ohidden2)
    ohidden4 = Conv2D(8,3,activation="elu",padding="same")(ohidden3)
    ohidden4  = BatchNormalization()(ohidden4)
    oflatten = Flatten()(ohidden4)
    
    
    embeddinglayer = Embedding(input_dim=20, output_dim=64)(embedding_input)
    gru1 = Bidirectional(GRU(64,return_sequences=True))(embeddinglayer)
    gru2 = GRU(64)(gru1)
    eflatten = Flatten()(gru2)
    
    
    
    
    bdense1  = Dense(200,activation="relu",name="blosumDense1")(bflatten)
    bdense1  = BatchNormalization(name="blosumBN1")(bdense1)
    bdense1  = Dropout(0.7,name="blosumDO1")(bdense1)

    
    odense1  = Dense(200,activation="relu")(oflatten)
    odense1  = BatchNormalization()(odense1)
    odense1  = Dropout(0.7)(odense1)
    
    edense1  = Dense(200,activation="relu")(eflatten)
    edense1  = BatchNormalization()(edense1)
    edense1  = Dropout(0.7)(edense1)
    
    dense1  = Concatenate(axis=1)([bdense1, odense1, edense1])
    
    dense2  = Dense(200,activation="relu")(dense1)
    dense2  = BatchNormalization()(dense2)
    dense2  = Dropout(0.8)(dense2)

    dense3  = Dense(200,activation="relu")(dense2)
    dense3  = BatchNormalization()(dense3)
    dense3  = Dropout(0.8)(dense3)
    
    
    
    dense4  = Dense(200,activation="relu")(dense3)
    dense4  = BatchNormalization()(dense4)
    dense4  = Dropout(0.8)(dense4)
        
    dense5  = Dense(200,activation="relu")(dense4)
    dense5  = BatchNormalization()(dense5)
    dense5  = Dropout(0.8)(dense5)

    dense6  = Dense(200,activation="relu")(dense5)
    dense6  = BatchNormalization()(dense6)
    dense6  = Dropout(0.8)(dense6)
    
    dense6  = Dense(50,activation="relu")(dense5)
    dense6  = BatchNormalization()(dense6)
    dense6  = Dropout(0.8)(dense6)
    
    outputs = Dense(1,activation="linear")(dense6)

    # dense3

    
    model = keras.Model(inputs=[blosum62_input,onehot_input,embedding_input], outputs=outputs)
    # model.summary()

    return model

def SPRCC(y_true, y_pred):
    return ( tf.py_function(spearmanr, [tf.cast(y_pred, tf.float32),tf.cast(y_true, tf.float32)], Tout = tf.float32) )

# %%
[X_train, X_test, y_train, y_test]=train_test_split(seqs,meas,test_size=0.2,random_state=10)
X_train
# Out:
# 12082    LLDFELACL
# 17871    HIIDSFNIR
# 11226    NLVPMVATV
# 10312    YMYQYIQEL
# 15415    AMDTHLYFE
#            ...
# 14797    FTLMAAILA
# 17259    VWKQLFPEL
# 11312    YLHPKDKYL
# 17261    VYERQPCWY
# 11257    YLLGRPPNA
# Name: sequence, Length: 7240, dtype: object

# %%
seed(123454566)
tensorflow.random.set_seed(123454566)
######### model parameters ##############
epochs = 5000
batch_size = 8
patience = 100
optimizer = "nadam"
########################################

def train_test_model(epochs = 100, batch_size = 16, patience=2, optimizer= "nadam"):
    

    onehot_input = np.array(blosum_seqs).reshape(-1,24,9,1)

    blosum_input = np.array(onehot_seqs).reshape(-1,20,9,1)

    embedding_input = np.array(embedding_seqs).reshape(-1,9)


#         X = np.array(reducedProp_seqs).reshape(-1,6,9,1)

    
    Y = meas
    
    model = build_model()
    model.summary()
    model.compile(
#         loss=inequaility_loss,
        loss = "mse",
        optimizer=optimizer,
        metrics=[SPRCC]
    )
    es = EarlyStopping(monitor='val_loss',mode="min",patience=patience)
    mc = ModelCheckpoint('best_combined_model.h5',monitor='val_loss', mode='min', save_best_only=True)
    
#     [X_train, X_test, y_train, y_test]=train_test_split(X,Y,test_size=0.2,random_state=10)
    train_indices,test_indices = next(ShuffleSplit(test_size=.20, random_state = 7).split(seqs,meas))
    X_train = [blosum_input[train_indices],onehot_input[train_indices],embedding_input[train_indices]]
    X_test  = [blosum_input[test_indices],onehot_input[test_indices],embedding_input[test_indices]]
    y_train = np.array([list(meas)[x] for x in train_indices])
    y_test = np.array([list(meas)[x] for x in test_indices])
    
    history = model.fit(X_train,y_train,batch_size=batch_size,epochs = epochs, validation_split=0.1,callbacks=[es,mc])
    return (history,model,X_test,y_test)

def plot_model(history=False,model=None,X_test=None,y_test=None):
    if history:
        plt.figure()
        sns.lineplot(data=pd.DataFrame(history.history).reset_index(),x="index",y="loss")
        sns.lineplot(data=pd.DataFrame(history.history).reset_index(),x="index",y="val_loss")
        plt.legend(["loss","val_loss"])
    y_pred = model.predict(X_test)
    ## transform y_test
    
#     bat1 = y_test*(y_test<=1)
#     bat2 = (y_test-2)*(y_test>=2)*(y_test<=3)
#     bat3 = (y_test-4)*(y_test>=4)
#     y_test = bat1+bat2+bat3
    plt.figure()
    sns.scatterplot(x=y_test,y=y_pred.squeeze())
    R, pv = spearmanr(y_test,y_pred.squeeze())
    plt.title("SRCC: {0:0.4f}".format(R))

# %%
train_test_model(epochs = 5000
batch_size = 8
patience = 100
optimizer = "nadam")
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_31 (InputLayer)           [(None, 20, 9, 1)]   0
# __________________________________________________________________________________________________
# input_32 (InputLayer)           [(None, 24, 9, 1)]   0
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 20, 9, 16)    800         input_31[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 24, 9, 16)    800         input_32[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 20, 9, 16)    6416        conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 24, 9, 16)    6416        conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 20, 9, 16)    64          conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 24, 9, 16)    64          conv2d_85[0][0]
# __________________________________________________________________________________________________
# input_33 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 20, 9, 8)     3208        batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 24, 9, 8)     3208        batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, None, 64)     1280        input_33[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 20, 9, 8)     584         conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 24, 9, 8)     584         conv2d_86[0][0]
# __________________________________________________________________________________________________
# bidirectional_10 (Bidirectional (None, None, 128)    49920       embedding_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 20, 9, 8)     32          conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 24, 9, 8)     32          conv2d_87[0][0]
# __________________________________________________________________________________________________
# gru_21 (GRU)                    (None, 64)           37248       bidirectional_10[0][0]
# __________________________________________________________________________________________________
# flatten_30 (Flatten)            (None, 1440)         0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 1728)         0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# flatten_32 (Flatten)            (None, 64)           0           gru_21[0][0]
# __________________________________________________________________________________________________
# blosumDense1 (Dense)            (None, 200)          288200      flatten_30[0][0]
# __________________________________________________________________________________________________
# dense_96 (Dense)                (None, 200)          345800      flatten_31[0][0]
# __________________________________________________________________________________________________
# dense_97 (Dense)                (None, 200)          13000       flatten_32[0][0]
# __________________________________________________________________________________________________
# blosumBN1 (BatchNormalization)  (None, 200)          800         blosumDense1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 200)          800         dense_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 200)          800         dense_97[0][0]
# __________________________________________________________________________________________________
# blosumDO1 (Dropout)             (None, 200)          0           blosumBN1[0][0]
# __________________________________________________________________________________________________
# dropout_86 (Dropout)            (None, 200)          0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# dropout_87 (Dropout)            (None, 200)          0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 600)          0           blosumDO1[0][0]
#                                                                  dropout_86[0][0]
#                                                                  dropout_87[0][0]
# __________________________________________________________________________________________________
# dense_98 (Dense)                (None, 200)          120200      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 200)          800         dense_98[0][0]
# __________________________________________________________________________________________________
# dropout_88 (Dropout)            (None, 200)          0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# dense_99 (Dense)                (None, 200)          40200       dropout_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 200)          800         dense_99[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 200)          0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# dense_100 (Dense)               (None, 200)          40200       dropout_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 200)          800         dense_100[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 200)          0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# dense_101 (Dense)               (None, 200)          40200       dropout_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 200)          800         dense_101[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 200)          0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# dense_103 (Dense)               (None, 50)           10050       dropout_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 50)           200         dense_103[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 50)           0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# dense_104 (Dense)               (None, 1)            51          dropout_93[0][0]
# ==================================================================================================
# Total params: 1,014,357
# Trainable params: 1,011,361
# Non-trainable params: 2,996
# __________________________________________________________________________________________________
# Epoch 1/100
# 408/408 [==============================] - 15s 36ms/step - loss: 11.9557 - SPRCC: 0.0139 - val_loss: 3.7527 - val_SPRCC: 0.0178
# Epoch 2/100
#  67/408 [===>..........................] - ETA: 10s - loss: 6.8182 - SPRCC: 0.0117

# %%
blosum_input = np.array(blosum_seqs).reshape(-1,24,9,1)

onehot_input = np.array(onehot_seqs).reshape(-1,20,9,1)

embedding_input = np.array(embedding_seqs).reshape(-1,9)


train_indices,test_indices = next(ShuffleSplit(test_size=.20, random_state = 7).split(seqs,meas))
X_train = [blosum_input[train_indices],onehot_input[train_indices],embedding_input[train_indices]]
X_test  = [blosum_input[test_indices],onehot_input[test_indices],embedding_input[test_indices]]

# %%
model = build_model()
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 20, 9, 1)]   0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 24, 9, 1)]   0
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 20, 9, 16)    800         input_19[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 24, 9, 16)    800         input_20[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 20, 9, 16)    6416        conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 24, 9, 16)    6416        conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 20, 9, 16)    64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 24, 9, 16)    64          conv2d_53[0][0]
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 20, 9, 8)     3208        batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 24, 9, 8)     3208        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, None, 64)     1280        input_21[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 20, 9, 8)     584         conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 24, 9, 8)     584         conv2d_54[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, None, 128)    49920       embedding_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 20, 9, 8)     32          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 24, 9, 8)     32          conv2d_55[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    (None, 64)           37248       bidirectional_6[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 1440)         0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 1728)         0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 64)           0           gru_13[0][0]
# __________________________________________________________________________________________________
# blosumDense1 (Dense)            (None, 200)          288200      flatten_18[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 200)          345800      flatten_19[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 200)          13000       flatten_20[0][0]
# __________________________________________________________________________________________________
# blosumBN1 (BatchNormalization)  (None, 200)          800         blosumDense1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 200)          800         dense_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 200)          800         dense_61[0][0]
# __________________________________________________________________________________________________
# blosumDO1 (Dropout)             (None, 200)          0           blosumBN1[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 200)          0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 200)          0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 600)          0           blosumDO1[0][0]
#                                                                  dropout_54[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 200)          120200      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 200)          800         dense_62[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 200)          0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 200)          40200       dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 200)          800         dense_63[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 200)          0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 200)          40200       dropout_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 200)          800         dense_64[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 200)          0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 200)          0           dropout_56[0][0]
#                                                                  dropout_58[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 200)          40200       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 200)          800         dense_65[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 200)          0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 50)           10050       dropout_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 50)           200         dense_67[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 50)           0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 1)            51          dropout_61[0][0]
# ==================================================================================================
# Total params: 1,014,357
# Trainable params: 1,011,361
# Non-trainable params: 2,996
# __________________________________________________________________________________________________
